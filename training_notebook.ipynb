# %%
# !pip install tensorflow
# !pip install mmap_ninja
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting mmap_ninja
#   Downloading mmap_ninja-0.7.3-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy in ./.venv/lib/python3.10/site-packages (from mmap_ninja) (1.26.3)
# Collecting tqdm (from mmap_ninja)
#   Downloading tqdm-4.66.1-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 594.1 kB/s eta 0:00:00a 0:00:01
# Downloading mmap_ninja-0.7.3-py3-none-any.whl (14 kB)
# Downloading tqdm-4.66.1-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 1.8 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: tqdm, mmap_ninja
# Successfully installed mmap_ninja-0.7.3 tqdm-4.66.1

# %%
TRAIN_DIR = 'trained_models/hey_jarvis_custom_trainer'

GENERAL_NEGATIVE_DIR = '/Volumes/MachineLearning/training_features/background_noise_features_for_training'
ADVERSARIAL_NEGATIVE_DIR = '/Volumes/MachineLearning/new_style_hey_jarvis/generated_negative'
POSITIVE_FEATURES_DIR = '/Volumes/MachineLearning/new_style_hey_jarvis/generated_positive'

# Each of the three feature directories should have the following structure:
#  testing/
#    ragged_mmap_folders_ending_in_mmap
#  training/
#    ragged_mmap_folders_ending_in_mmap
#  validation/
#    ragged_mmap_folders_ending_in_mmap

# %%
# !python -m microwakeword.model_train_eval \
--general_negative_dir={GENERAL_NEGATIVE_DIR} \
--adversarial_negative_dir={ADVERSARIAL_NEGATIVE_DIR} \
--positive_dir={POSITIVE_FEATURES_DIR} \
--train_dir={TRAIN_DIR} \
--batch_size 100 \
--how_many_training_steps 10000,10000 \
--learning_rate 0.0005,0.00025 \
--general_negative_probability 0.33,0.5 \
--positive_probability 0.33,0.25 \
--general_negative_weight 4,4 \
--adversarial_negative_weight 3,3 \
--positive_weight 1,1 \
--train 1 \
--restore_checkpoint 1 \
--clip_duration_ms 1490 \
inception \
--cnn1_filters '32' \
--cnn1_kernel_sizes '5' \
--cnn1_strides '1' \
--cnn2_filters1 '16,16,16' \
--cnn2_filters2 '32,64,70' \
--cnn2_kernel_sizes '3,5,5' \
--cnn2_strides '1,1,1' \
--cnn2_use_one_step_stream=0 \
--dropout 0.5 \
--bn_scale 0
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(100, 74, 40)]              0         []
#
#  tf.expand_dims (TFOpLambda  (100, 74, 1, 40)             0         ['input_1[0][0]']
#  )
#
#  stream (Stream)             (100, 70, 1, 32)             6400      ['tf.expand_dims[0][0]']
#
#  batch_normalization (Batch  (100, 70, 1, 32)             96        ['stream[0][0]']
#  Normalization)
#
#  activation (Activation)     (100, 70, 1, 32)             0         ['batch_normalization[0][0]']
#
#  conv2d_4 (Conv2D)           (100, 70, 1, 16)             512       ['activation[0][0]']
#
#  batch_normalization_4 (Bat  (100, 70, 1, 16)             48        ['conv2d_4[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (100, 70, 1, 16)             0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  conv2d_2 (Conv2D)           (100, 70, 1, 16)             512       ['activation[0][0]']
#
#  stream_2 (Stream)           (100, 70, 1, 16)             768       ['activation_4[0][0]']
#
#  batch_normalization_2 (Bat  (100, 70, 1, 16)             48        ['conv2d_2[0][0]']
#  chNormalization)
#
#  batch_normalization_5 (Bat  (100, 70, 1, 16)             48        ['stream_2[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (100, 70, 1, 16)             0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  activation_5 (Activation)   (100, 70, 1, 16)             0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  conv2d_1 (Conv2D)           (100, 70, 1, 16)             512       ['activation[0][0]']
#
#  stream_1 (Stream)           (100, 70, 1, 16)             768       ['activation_2[0][0]']
#
#  stream_3 (Stream)           (100, 70, 1, 16)             768       ['activation_5[0][0]']
#
#  batch_normalization_1 (Bat  (100, 70, 1, 16)             48        ['conv2d_1[0][0]']
#  chNormalization)
#
#  batch_normalization_3 (Bat  (100, 70, 1, 16)             48        ['stream_1[0][0]']
#  chNormalization)
#
#  batch_normalization_6 (Bat  (100, 70, 1, 16)             48        ['stream_3[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (100, 70, 1, 16)             0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  activation_3 (Activation)   (100, 70, 1, 16)             0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  activation_6 (Activation)   (100, 70, 1, 16)             0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  concatenate (Concatenate)   (100, 70, 1, 48)             0         ['activation_1[0][0]',
#                                                                      'activation_3[0][0]',
#                                                                      'activation_6[0][0]']
#
#  conv2d_7 (Conv2D)           (100, 70, 1, 32)             1536      ['concatenate[0][0]']
#
#  batch_normalization_7 (Bat  (100, 70, 1, 32)             96        ['conv2d_7[0][0]']
#  chNormalization)
#
#  activation_7 (Activation)   (100, 70, 1, 32)             0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  conv2d_11 (Conv2D)          (100, 70, 1, 16)             512       ['activation_7[0][0]']
#
#  batch_normalization_11 (Ba  (100, 70, 1, 16)             48        ['conv2d_11[0][0]']
#  tchNormalization)
#
#  activation_11 (Activation)  (100, 70, 1, 16)             0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  conv2d_9 (Conv2D)           (100, 70, 1, 16)             512       ['activation_7[0][0]']
#
#  stream_5 (Stream)           (100, 70, 1, 16)             1280      ['activation_11[0][0]']
#
#  batch_normalization_9 (Bat  (100, 70, 1, 16)             48        ['conv2d_9[0][0]']
#  chNormalization)
#
#  batch_normalization_12 (Ba  (100, 70, 1, 16)             48        ['stream_5[0][0]']
#  tchNormalization)
#
#  activation_9 (Activation)   (100, 70, 1, 16)             0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  activation_12 (Activation)  (100, 70, 1, 16)             0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  conv2d_8 (Conv2D)           (100, 70, 1, 16)             512       ['activation_7[0][0]']
#
#  stream_4 (Stream)           (100, 70, 1, 16)             1280      ['activation_9[0][0]']
#
#  stream_6 (Stream)           (100, 70, 1, 16)             1280      ['activation_12[0][0]']
#
#  batch_normalization_8 (Bat  (100, 70, 1, 16)             48        ['conv2d_8[0][0]']
#  chNormalization)
#
#  batch_normalization_10 (Ba  (100, 70, 1, 16)             48        ['stream_4[0][0]']
#  tchNormalization)
#
#  batch_normalization_13 (Ba  (100, 70, 1, 16)             48        ['stream_6[0][0]']
#  tchNormalization)
#
#  activation_8 (Activation)   (100, 70, 1, 16)             0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  activation_10 (Activation)  (100, 70, 1, 16)             0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  activation_13 (Activation)  (100, 70, 1, 16)             0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  concatenate_1 (Concatenate  (100, 70, 1, 48)             0         ['activation_8[0][0]',
#  )                                                                   'activation_10[0][0]',
#                                                                      'activation_13[0][0]']
#
#  conv2d_14 (Conv2D)          (100, 70, 1, 64)             3072      ['concatenate_1[0][0]']
#
#  batch_normalization_14 (Ba  (100, 70, 1, 64)             192       ['conv2d_14[0][0]']
#  tchNormalization)
#
#  activation_14 (Activation)  (100, 70, 1, 64)             0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  conv2d_18 (Conv2D)          (100, 70, 1, 16)             1024      ['activation_14[0][0]']
#
#  batch_normalization_18 (Ba  (100, 70, 1, 16)             48        ['conv2d_18[0][0]']
#  tchNormalization)
#
#  activation_18 (Activation)  (100, 70, 1, 16)             0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  conv2d_16 (Conv2D)          (100, 70, 1, 16)             1024      ['activation_14[0][0]']
#
#  stream_8 (Stream)           (100, 70, 1, 16)             1280      ['activation_18[0][0]']
#
#  batch_normalization_16 (Ba  (100, 70, 1, 16)             48        ['conv2d_16[0][0]']
#  tchNormalization)
#
#  batch_normalization_19 (Ba  (100, 70, 1, 16)             48        ['stream_8[0][0]']
#  tchNormalization)
#
#  activation_16 (Activation)  (100, 70, 1, 16)             0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  activation_19 (Activation)  (100, 70, 1, 16)             0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  conv2d_15 (Conv2D)          (100, 70, 1, 16)             1024      ['activation_14[0][0]']
#
#  stream_7 (Stream)           (100, 70, 1, 16)             1280      ['activation_16[0][0]']
#
#  stream_9 (Stream)           (100, 70, 1, 16)             1280      ['activation_19[0][0]']
#
#  batch_normalization_15 (Ba  (100, 70, 1, 16)             48        ['conv2d_15[0][0]']
#  tchNormalization)
#
#  batch_normalization_17 (Ba  (100, 70, 1, 16)             48        ['stream_7[0][0]']
#  tchNormalization)
#
#  batch_normalization_20 (Ba  (100, 70, 1, 16)             48        ['stream_9[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (100, 70, 1, 16)             0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  activation_17 (Activation)  (100, 70, 1, 16)             0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  activation_20 (Activation)  (100, 70, 1, 16)             0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  concatenate_2 (Concatenate  (100, 70, 1, 48)             0         ['activation_15[0][0]',
#  )                                                                   'activation_17[0][0]',
#                                                                      'activation_20[0][0]']
#
#  conv2d_21 (Conv2D)          (100, 70, 1, 70)             3360      ['concatenate_2[0][0]']
#
#  batch_normalization_21 (Ba  (100, 70, 1, 70)             210       ['conv2d_21[0][0]']
#  tchNormalization)
#
#  activation_21 (Activation)  (100, 70, 1, 70)             0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  stream_10 (Stream)          (100, 70)                    0         ['activation_21[0][0]']
#
#  dropout (Dropout)           (100, 70)                    0         ['stream_10[0][0]']
#
#  dense (Dense)               (100, 1)                     71        ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 32025 (125.10 KB)
# Trainable params: 31053 (121.30 KB)
# Non-trainable params: 972 (3.80 KB)
# __________________________________________________________________________________________________
# INFO:absl:None
# INFO:absl:Step #5: rate 0.000500, accuracy 37.60%, recall 89.82%, precision 31.16%, cross entropy 0.913043
# INFO:absl:Step #10: rate 0.000500, accuracy 43.20%, recall 90.69%, precision 36.54%, cross entropy 0.844024
# INFO:absl:Step #15: rate 0.000500, accuracy 49.20%, recall 90.90%, precision 37.30%, cross entropy 0.786118
# INFO:absl:Step #20: rate 0.000500, accuracy 50.40%, recall 85.27%, precision 39.63%, cross entropy 0.746451
# INFO:absl:Step #25: rate 0.000500, accuracy 55.80%, recall 84.26%, precision 42.25%, cross entropy 0.719721
# INFO:absl:Step #30: rate 0.000500, accuracy 64.40%, recall 87.50%, precision 48.06%, cross entropy 0.665140
# INFO:absl:Step #35: rate 0.000500, accuracy 67.40%, recall 81.12%, precision 53.43%, cross entropy 0.600285
# INFO:absl:Step #40: rate 0.000500, accuracy 71.00%, recall 79.31%, precision 55.75%, cross entropy 0.559496
# INFO:absl:Step #45: rate 0.000500, accuracy 77.40%, recall 86.92%, precision 60.73%, cross entropy 0.500230
# INFO:absl:Step #50: rate 0.000500, accuracy 74.20%, recall 79.44%, precision 58.34%, cross entropy 0.515932
# INFO:absl:Step #55: rate 0.000500, accuracy 81.80%, recall 79.19%, precision 71.45%, cross entropy 0.448138
# INFO:absl:Step #60: rate 0.000500, accuracy 79.80%, recall 78.78%, precision 60.93%, cross entropy 0.472835
# INFO:absl:Step #65: rate 0.000500, accuracy 85.60%, recall 78.59%, precision 76.77%, cross entropy 0.371215
# INFO:absl:Step #70: rate 0.000500, accuracy 84.40%, recall 77.16%, precision 73.62%, cross entropy 0.381392
# INFO:absl:Step #75: rate 0.000500, accuracy 81.40%, recall 71.12%, precision 74.15%, cross entropy 0.395344
# INFO:absl:Step #80: rate 0.000500, accuracy 87.00%, recall 83.52%, precision 74.75%, cross entropy 0.369562
# INFO:absl:Step #85: rate 0.000500, accuracy 86.00%, recall 77.92%, precision 79.69%, cross entropy 0.358142
# INFO:absl:Step #90: rate 0.000500, accuracy 84.60%, recall 75.14%, precision 79.34%, cross entropy 0.350874
# INFO:absl:Step #95: rate 0.000500, accuracy 87.40%, recall 80.61%, precision 77.44%, cross entropy 0.314816
# INFO:absl:Step #100: rate 0.000500, accuracy 86.00%, recall 75.33%, precision 83.34%, cross entropy 0.331114
# INFO:absl:Step #105: rate 0.000500, accuracy 87.00%, recall 74.39%, precision 83.46%, cross entropy 0.315833
# INFO:absl:Step #110: rate 0.000500, accuracy 87.40%, recall 75.14%, precision 86.83%, cross entropy 0.317415
# INFO:absl:Step #115: rate 0.000500, accuracy 86.60%, recall 75.81%, precision 81.39%, cross entropy 0.313199
# INFO:absl:Step #120: rate 0.000500, accuracy 88.60%, recall 76.92%, precision 88.63%, cross entropy 0.294759
# INFO:absl:Step #125: rate 0.000500, accuracy 86.20%, recall 75.34%, precision 77.32%, cross entropy 0.344347
# INFO:absl:Step #130: rate 0.000500, accuracy 89.60%, recall 82.68%, precision 85.65%, cross entropy 0.268900
# INFO:absl:Step #135: rate 0.000500, accuracy 86.60%, recall 76.33%, precision 81.62%, cross entropy 0.327443
# INFO:absl:Step #140: rate 0.000500, accuracy 89.60%, recall 78.96%, precision 88.67%, cross entropy 0.279251
# INFO:absl:Step #145: rate 0.000500, accuracy 87.60%, recall 78.17%, precision 82.26%, cross entropy 0.295325
# INFO:absl:Step #150: rate 0.000500, accuracy 90.00%, recall 80.54%, precision 88.82%, cross entropy 0.254810
# INFO:absl:Step #155: rate 0.000500, accuracy 89.00%, recall 80.77%, precision 84.51%, cross entropy 0.280573
# INFO:absl:Step #160: rate 0.000500, accuracy 88.80%, recall 81.13%, precision 85.13%, cross entropy 0.276238
# INFO:absl:Step #165: rate 0.000500, accuracy 88.20%, recall 80.91%, precision 79.15%, cross entropy 0.290642
# INFO:absl:Step #170: rate 0.000500, accuracy 87.20%, recall 76.68%, precision 84.11%, cross entropy 0.291324
# INFO:absl:Step #175: rate 0.000500, accuracy 88.60%, recall 75.47%, precision 89.61%, cross entropy 0.265632
# INFO:absl:Step #180: rate 0.000500, accuracy 90.00%, recall 79.42%, precision 89.04%, cross entropy 0.260795
# INFO:absl:Step #185: rate 0.000500, accuracy 88.40%, recall 80.96%, precision 80.78%, cross entropy 0.277657
# INFO:absl:Step #190: rate 0.000500, accuracy 90.00%, recall 80.07%, precision 85.83%, cross entropy 0.260788
# INFO:absl:Step #195: rate 0.000500, accuracy 88.60%, recall 79.83%, precision 86.16%, cross entropy 0.270478
# INFO:absl:Step #200: rate 0.000500, accuracy 88.00%, recall 80.14%, precision 84.56%, cross entropy 0.287218
# INFO:absl:Step #205: rate 0.000500, accuracy 90.40%, recall 80.11%, precision 91.43%, cross entropy 0.249901
# INFO:absl:Step #210: rate 0.000500, accuracy 91.40%, recall 83.65%, precision 90.57%, cross entropy 0.238228
# INFO:absl:Step #215: rate 0.000500, accuracy 90.00%, recall 81.29%, precision 88.46%, cross entropy 0.251919
# INFO:absl:Step #220: rate 0.000500, accuracy 89.20%, recall 79.81%, precision 85.09%, cross entropy 0.248355
# INFO:absl:Step #225: rate 0.000500, accuracy 90.00%, recall 82.52%, precision 84.94%, cross entropy 0.258614
# INFO:absl:Step #230: rate 0.000500, accuracy 90.00%, recall 80.36%, precision 91.20%, cross entropy 0.256714
# INFO:absl:Step #235: rate 0.000500, accuracy 93.60%, recall 89.00%, precision 91.12%, cross entropy 0.199039
# INFO:absl:Step #240: rate 0.000500, accuracy 89.20%, recall 81.06%, precision 89.20%, cross entropy 0.245412
# INFO:absl:Step #245: rate 0.000500, accuracy 92.60%, recall 88.31%, precision 89.86%, cross entropy 0.205712
# INFO:absl:Step #250: rate 0.000500, accuracy 91.80%, recall 83.63%, precision 88.33%, cross entropy 0.216175
# INFO:absl:Step #255: rate 0.000500, accuracy 91.00%, recall 82.17%, precision 89.08%, cross entropy 0.234660
# INFO:absl:Step #260: rate 0.000500, accuracy 91.60%, recall 81.12%, precision 93.63%, cross entropy 0.210357
# INFO:absl:Step #265: rate 0.000500, accuracy 90.20%, recall 81.00%, precision 86.93%, cross entropy 0.271168
# INFO:absl:Step #270: rate 0.000500, accuracy 90.00%, recall 81.71%, precision 86.86%, cross entropy 0.226752
# INFO:absl:Step #275: rate 0.000500, accuracy 91.40%, recall 80.14%, precision 93.12%, cross entropy 0.210200
# INFO:absl:Step #280: rate 0.000500, accuracy 90.20%, recall 83.30%, precision 87.83%, cross entropy 0.238630
# INFO:absl:Step #285: rate 0.000500, accuracy 91.60%, recall 83.63%, precision 89.55%, cross entropy 0.219924
# INFO:absl:Step #290: rate 0.000500, accuracy 91.60%, recall 82.46%, precision 92.86%, cross entropy 0.224877
# INFO:absl:Step #295: rate 0.000500, accuracy 93.80%, recall 86.40%, precision 93.84%, cross entropy 0.207840
# INFO:absl:Step #300: rate 0.000500, accuracy 92.20%, recall 89.23%, precision 84.16%, cross entropy 0.195054
# INFO:absl:Step #305: rate 0.000500, accuracy 90.80%, recall 83.15%, precision 88.03%, cross entropy 0.226260
# INFO:absl:Step #310: rate 0.000500, accuracy 90.80%, recall 80.57%, precision 91.68%, cross entropy 0.212725
# INFO:absl:Step #315: rate 0.000500, accuracy 90.80%, recall 84.35%, precision 88.62%, cross entropy 0.239590
# INFO:absl:Step #320: rate 0.000500, accuracy 91.60%, recall 85.57%, precision 88.47%, cross entropy 0.207127
# INFO:absl:Step #325: rate 0.000500, accuracy 91.20%, recall 83.74%, precision 88.74%, cross entropy 0.218003
# INFO:absl:Step #330: rate 0.000500, accuracy 91.00%, recall 80.88%, precision 91.48%, cross entropy 0.212057
# INFO:absl:Step #335: rate 0.000500, accuracy 89.80%, recall 78.51%, precision 89.84%, cross entropy 0.228410
# INFO:absl:Step #340: rate 0.000500, accuracy 92.20%, recall 81.16%, precision 92.55%, cross entropy 0.212111
# INFO:absl:Step #345: rate 0.000500, accuracy 91.80%, recall 82.00%, precision 90.52%, cross entropy 0.208584
# INFO:absl:Step #350: rate 0.000500, accuracy 90.80%, recall 84.91%, precision 85.18%, cross entropy 0.220933
# INFO:absl:Step #355: rate 0.000500, accuracy 91.60%, recall 87.89%, precision 85.46%, cross entropy 0.198683
# INFO:absl:Step #360: rate 0.000500, accuracy 88.80%, recall 73.97%, precision 95.73%, cross entropy 0.273977
# INFO:absl:Step #365: rate 0.000500, accuracy 91.00%, recall 82.43%, precision 90.01%, cross entropy 0.223378
# INFO:absl:Step #370: rate 0.000500, accuracy 94.20%, recall 89.93%, precision 92.39%, cross entropy 0.174261
# INFO:absl:Step #375: rate 0.000500, accuracy 93.00%, recall 86.94%, precision 93.28%, cross entropy 0.193279
# INFO:absl:Step #380: rate 0.000500, accuracy 92.40%, recall 89.42%, precision 89.14%, cross entropy 0.221556
# INFO:absl:Step #385: rate 0.000500, accuracy 93.20%, recall 85.68%, precision 93.98%, cross entropy 0.192722
# INFO:absl:Step #390: rate 0.000500, accuracy 90.60%, recall 84.83%, precision 89.00%, cross entropy 0.234886
# INFO:absl:Step #395: rate 0.000500, accuracy 92.40%, recall 87.72%, precision 91.13%, cross entropy 0.216269
# INFO:absl:Step #400: rate 0.000500, accuracy 91.00%, recall 84.79%, precision 87.59%, cross entropy 0.233116
# INFO:absl:Step #405: rate 0.000500, accuracy 92.60%, recall 87.17%, precision 91.74%, cross entropy 0.190943
# INFO:absl:Step #410: rate 0.000500, accuracy 89.80%, recall 78.84%, precision 89.45%, cross entropy 0.212274
# INFO:absl:Step #415: rate 0.000500, accuracy 91.40%, recall 81.42%, precision 91.72%, cross entropy 0.203131
# INFO:absl:Step #420: rate 0.000500, accuracy 92.40%, recall 85.16%, precision 91.59%, cross entropy 0.188527
# INFO:absl:Step #425: rate 0.000500, accuracy 93.40%, recall 87.88%, precision 90.92%, cross entropy 0.192430
# INFO:absl:Step #430: rate 0.000500, accuracy 92.80%, recall 83.93%, precision 95.35%, cross entropy 0.217242
# INFO:absl:Step #435: rate 0.000500, accuracy 92.00%, recall 86.73%, precision 89.65%, cross entropy 0.178754
# INFO:absl:Step #440: rate 0.000500, accuracy 91.40%, recall 85.73%, precision 89.54%, cross entropy 0.201821
# INFO:absl:Step #445: rate 0.000500, accuracy 91.80%, recall 85.52%, precision 90.09%, cross entropy 0.196336
# INFO:absl:Step #450: rate 0.000500, accuracy 91.40%, recall 82.73%, precision 92.21%, cross entropy 0.222004
# INFO:absl:Step #455: rate 0.000500, accuracy 93.40%, recall 88.47%, precision 91.51%, cross entropy 0.166406
# INFO:absl:Step #460: rate 0.000500, accuracy 93.20%, recall 88.91%, precision 88.67%, cross entropy 0.177181
# INFO:absl:Step #465: rate 0.000500, accuracy 93.20%, recall 85.25%, precision 94.18%, cross entropy 0.189621
# INFO:absl:Step #470: rate 0.000500, accuracy 92.60%, recall 85.71%, precision 89.41%, cross entropy 0.188809
# INFO:absl:Step #475: rate 0.000500, accuracy 93.40%, recall 89.21%, precision 90.67%, cross entropy 0.179165
# INFO:absl:Step #480: rate 0.000500, accuracy 91.40%, recall 82.58%, precision 89.42%, cross entropy 0.216256
# INFO:absl:Step #485: rate 0.000500, accuracy 93.60%, recall 86.49%, precision 93.31%, cross entropy 0.179716
# INFO:absl:Step #490: rate 0.000500, accuracy 92.20%, recall 84.40%, precision 91.53%, cross entropy 0.210253
# INFO:absl:Step #495: rate 0.000500, accuracy 92.80%, recall 88.51%, precision 87.43%, cross entropy 0.192435
# INFO:absl:Step #500: rate 0.000500, accuracy 93.80%, recall 85.52%, precision 94.49%, cross entropy 0.171762
# INFO:absl:Step 500: Validation accuracy = 88.13%, recall = 91.55%, precision = 71.53%, fpr = 13.10%, fnr = 8.45% (N=35649)
# INFO:absl:So far the best low false positive rate is 13.10% with false negative rate of 8.45%
# INFO:absl:Step #505: rate 0.000500, accuracy 91.80%, recall 83.35%, precision 93.85%, cross entropy 0.199100
# INFO:absl:Step #510: rate 0.000500, accuracy 91.40%, recall 85.22%, precision 90.92%, cross entropy 0.213126
# INFO:absl:Step #515: rate 0.000500, accuracy 92.80%, recall 86.47%, precision 90.79%, cross entropy 0.176245
# INFO:absl:Step #520: rate 0.000500, accuracy 92.60%, recall 87.21%, precision 88.89%, cross entropy 0.172491
# INFO:absl:Step #525: rate 0.000500, accuracy 90.40%, recall 82.40%, precision 91.27%, cross entropy 0.246359
# INFO:absl:Step #530: rate 0.000500, accuracy 94.00%, recall 88.80%, precision 91.98%, cross entropy 0.170070
# INFO:absl:Step #535: rate 0.000500, accuracy 94.00%, recall 89.44%, precision 91.87%, cross entropy 0.172801
# INFO:absl:Step #540: rate 0.000500, accuracy 93.80%, recall 87.27%, precision 94.23%, cross entropy 0.185389
# INFO:absl:Step #545: rate 0.000500, accuracy 94.00%, recall 89.24%, precision 92.36%, cross entropy 0.171034
# INFO:absl:Step #550: rate 0.000500, accuracy 91.20%, recall 85.24%, precision 89.18%, cross entropy 0.209739
# INFO:absl:Step #555: rate 0.000500, accuracy 91.40%, recall 82.75%, precision 92.86%, cross entropy 0.205446
# INFO:absl:Step #560: rate 0.000500, accuracy 91.80%, recall 91.02%, precision 84.23%, cross entropy 0.188946
# INFO:absl:Step #565: rate 0.000500, accuracy 93.60%, recall 88.77%, precision 90.83%, cross entropy 0.164841
# INFO:absl:Step #570: rate 0.000500, accuracy 94.80%, recall 89.32%, precision 96.02%, cross entropy 0.160223
# INFO:absl:Step #575: rate 0.000500, accuracy 93.20%, recall 85.96%, precision 93.95%, cross entropy 0.170843
# INFO:absl:Step #580: rate 0.000500, accuracy 94.00%, recall 90.08%, precision 91.19%, cross entropy 0.182169
# INFO:absl:Step #585: rate 0.000500, accuracy 93.20%, recall 87.55%, precision 91.90%, cross entropy 0.169241
# INFO:absl:Step #590: rate 0.000500, accuracy 90.40%, recall 82.80%, precision 90.35%, cross entropy 0.193996
# INFO:absl:Step #595: rate 0.000500, accuracy 92.00%, recall 84.62%, precision 92.48%, cross entropy 0.189378
# INFO:absl:Step #600: rate 0.000500, accuracy 92.60%, recall 88.33%, precision 90.98%, cross entropy 0.166898
# INFO:absl:Step #605: rate 0.000500, accuracy 92.60%, recall 89.86%, precision 86.72%, cross entropy 0.202457
# INFO:absl:Step #610: rate 0.000500, accuracy 92.00%, recall 85.13%, precision 91.31%, cross entropy 0.192589
# INFO:absl:Step #615: rate 0.000500, accuracy 91.80%, recall 91.18%, precision 82.14%, cross entropy 0.207749
# INFO:absl:Step #620: rate 0.000500, accuracy 93.60%, recall 86.60%, precision 91.74%, cross entropy 0.172775
# INFO:absl:Step #625: rate 0.000500, accuracy 93.20%, recall 85.65%, precision 93.39%, cross entropy 0.182471
# INFO:absl:Step #630: rate 0.000500, accuracy 94.60%, recall 91.00%, precision 92.65%, cross entropy 0.167713
# INFO:absl:Step #635: rate 0.000500, accuracy 93.40%, recall 86.92%, precision 94.41%, cross entropy 0.180816
# INFO:absl:Step #640: rate 0.000500, accuracy 93.60%, recall 88.73%, precision 92.63%, cross entropy 0.184266
# INFO:absl:Step #645: rate 0.000500, accuracy 93.60%, recall 88.82%, precision 90.35%, cross entropy 0.176551
# INFO:absl:Step #650: rate 0.000500, accuracy 93.60%, recall 87.33%, precision 92.44%, cross entropy 0.162953
# INFO:absl:Step #655: rate 0.000500, accuracy 92.20%, recall 83.53%, precision 92.73%, cross entropy 0.201729
# INFO:absl:Step #660: rate 0.000500, accuracy 93.20%, recall 86.55%, precision 91.22%, cross entropy 0.155478
# INFO:absl:Step #665: rate 0.000500, accuracy 94.40%, recall 90.20%, precision 91.44%, cross entropy 0.163471
# INFO:absl:Step #670: rate 0.000500, accuracy 93.60%, recall 89.70%, precision 89.70%, cross entropy 0.176115
# INFO:absl:Step #675: rate 0.000500, accuracy 92.20%, recall 85.14%, precision 90.58%, cross entropy 0.191724
# INFO:absl:Step #680: rate 0.000500, accuracy 91.80%, recall 82.23%, precision 91.30%, cross entropy 0.192891
# INFO:absl:Step #685: rate 0.000500, accuracy 92.40%, recall 82.67%, precision 95.26%, cross entropy 0.190313
# INFO:absl:Step #690: rate 0.000500, accuracy 95.00%, recall 93.61%, precision 91.10%, cross entropy 0.148877
# INFO:absl:Step #695: rate 0.000500, accuracy 93.40%, recall 88.93%, precision 91.60%, cross entropy 0.160637
# INFO:absl:Step #700: rate 0.000500, accuracy 94.80%, recall 89.48%, precision 93.10%, cross entropy 0.157780
# INFO:absl:Step #705: rate 0.000500, accuracy 92.80%, recall 84.36%, precision 94.17%, cross entropy 0.158900
# INFO:absl:Step #710: rate 0.000500, accuracy 92.80%, recall 86.05%, precision 90.50%, cross entropy 0.163775
# INFO:absl:Step #715: rate 0.000500, accuracy 94.60%, recall 87.55%, precision 96.04%, cross entropy 0.141723
# INFO:absl:Step #720: rate 0.000500, accuracy 92.80%, recall 89.93%, precision 86.67%, cross entropy 0.172638
# INFO:absl:Step #725: rate 0.000500, accuracy 93.40%, recall 86.61%, precision 92.04%, cross entropy 0.186921
# INFO:absl:Step #730: rate 0.000500, accuracy 95.00%, recall 88.34%, precision 97.27%, cross entropy 0.147357
# INFO:absl:Step #735: rate 0.000500, accuracy 94.20%, recall 87.25%, precision 95.40%, cross entropy 0.145259
# INFO:absl:Step #740: rate 0.000500, accuracy 93.40%, recall 89.02%, precision 91.44%, cross entropy 0.141891
# INFO:absl:Step #745: rate 0.000500, accuracy 93.00%, recall 90.05%, precision 89.71%, cross entropy 0.158687
# INFO:absl:Step #750: rate 0.000500, accuracy 93.60%, recall 90.22%, precision 91.02%, cross entropy 0.164774
# INFO:absl:Step #755: rate 0.000500, accuracy 95.20%, recall 91.31%, precision 92.80%, cross entropy 0.146520
# INFO:absl:Step #760: rate 0.000500, accuracy 94.00%, recall 89.91%, precision 92.05%, cross entropy 0.155778
# INFO:absl:Step #765: rate 0.000500, accuracy 94.00%, recall 88.29%, precision 93.41%, cross entropy 0.143162
# INFO:absl:Step #770: rate 0.000500, accuracy 92.60%, recall 85.68%, precision 92.58%, cross entropy 0.175496
# INFO:absl:Step #775: rate 0.000500, accuracy 94.00%, recall 88.13%, precision 94.26%, cross entropy 0.166808
# INFO:absl:Step #780: rate 0.000500, accuracy 95.60%, recall 89.69%, precision 97.48%, cross entropy 0.127172
# INFO:absl:Step #785: rate 0.000500, accuracy 94.40%, recall 92.01%, precision 86.73%, cross entropy 0.162841
# INFO:absl:Step #790: rate 0.000500, accuracy 93.40%, recall 87.09%, precision 92.09%, cross entropy 0.181977
# INFO:absl:Step #795: rate 0.000500, accuracy 93.20%, recall 82.98%, precision 98.78%, cross entropy 0.172938
# INFO:absl:Step #800: rate 0.000500, accuracy 93.60%, recall 89.27%, precision 88.92%, cross entropy 0.152735
# INFO:absl:Step #805: rate 0.000500, accuracy 93.80%, recall 87.49%, precision 91.58%, cross entropy 0.160920
# INFO:absl:Step #810: rate 0.000500, accuracy 94.60%, recall 88.55%, precision 96.40%, cross entropy 0.156275
# INFO:absl:Step #815: rate 0.000500, accuracy 92.40%, recall 86.10%, precision 91.01%, cross entropy 0.196742
# INFO:absl:Step #820: rate 0.000500, accuracy 94.00%, recall 91.39%, precision 90.94%, cross entropy 0.141031
# INFO:absl:Step #825: rate 0.000500, accuracy 95.00%, recall 89.13%, precision 96.13%, cross entropy 0.157852
# INFO:absl:Step #830: rate 0.000500, accuracy 97.00%, recall 94.89%, precision 95.24%, cross entropy 0.112557
# INFO:absl:Step #835: rate 0.000500, accuracy 94.60%, recall 89.73%, precision 94.38%, cross entropy 0.141093
# INFO:absl:Step #840: rate 0.000500, accuracy 95.20%, recall 92.22%, precision 94.35%, cross entropy 0.153566
# INFO:absl:Step #845: rate 0.000500, accuracy 93.80%, recall 87.23%, precision 94.36%, cross entropy 0.166588
# INFO:absl:Step #850: rate 0.000500, accuracy 94.40%, recall 91.25%, precision 91.42%, cross entropy 0.151663
# INFO:absl:Step #855: rate 0.000500, accuracy 93.20%, recall 88.08%, precision 91.28%, cross entropy 0.155310
# INFO:absl:Step #860: rate 0.000500, accuracy 95.20%, recall 87.85%, precision 97.16%, cross entropy 0.134537
# INFO:absl:Step #865: rate 0.000500, accuracy 94.00%, recall 87.13%, precision 93.18%, cross entropy 0.151375
# INFO:absl:Step #870: rate 0.000500, accuracy 93.40%, recall 89.65%, precision 91.93%, cross entropy 0.169799
# INFO:absl:Step #875: rate 0.000500, accuracy 94.40%, recall 90.08%, precision 93.97%, cross entropy 0.134277
# INFO:absl:Step #880: rate 0.000500, accuracy 94.20%, recall 90.27%, precision 90.63%, cross entropy 0.137053
# INFO:absl:Step #885: rate 0.000500, accuracy 93.40%, recall 89.07%, precision 88.80%, cross entropy 0.164565
# INFO:absl:Step #890: rate 0.000500, accuracy 94.60%, recall 90.47%, precision 92.27%, cross entropy 0.174237
# INFO:absl:Step #895: rate 0.000500, accuracy 95.00%, recall 88.48%, precision 96.78%, cross entropy 0.138050
# INFO:absl:Step #900: rate 0.000500, accuracy 95.60%, recall 89.96%, precision 96.00%, cross entropy 0.141969
# INFO:absl:Step #905: rate 0.000500, accuracy 94.00%, recall 87.60%, precision 96.48%, cross entropy 0.170903
# INFO:absl:Step #910: rate 0.000500, accuracy 93.60%, recall 90.81%, precision 89.63%, cross entropy 0.164585
# INFO:absl:Step #915: rate 0.000500, accuracy 94.60%, recall 89.87%, precision 92.70%, cross entropy 0.149325
# INFO:absl:Step #920: rate 0.000500, accuracy 95.60%, recall 92.02%, precision 92.45%, cross entropy 0.137276
# INFO:absl:Step #925: rate 0.000500, accuracy 93.60%, recall 87.61%, precision 92.43%, cross entropy 0.166540
# INFO:absl:Step #930: rate 0.000500, accuracy 94.00%, recall 86.69%, precision 94.25%, cross entropy 0.144528
# INFO:absl:Step #935: rate 0.000500, accuracy 94.60%, recall 88.92%, precision 92.96%, cross entropy 0.142032
# INFO:absl:Step #940: rate 0.000500, accuracy 93.80%, recall 90.97%, precision 88.48%, cross entropy 0.135557
# INFO:absl:Step #945: rate 0.000500, accuracy 95.80%, recall 91.12%, precision 96.06%, cross entropy 0.127633
# INFO:absl:Step #950: rate 0.000500, accuracy 93.40%, recall 85.55%, precision 94.94%, cross entropy 0.155988
# INFO:absl:Step #955: rate 0.000500, accuracy 93.60%, recall 89.59%, precision 89.56%, cross entropy 0.154600
# INFO:absl:Step #960: rate 0.000500, accuracy 95.20%, recall 95.10%, precision 89.60%, cross entropy 0.121955
# INFO:absl:Step #965: rate 0.000500, accuracy 93.80%, recall 88.65%, precision 93.03%, cross entropy 0.142563
# INFO:absl:Step #970: rate 0.000500, accuracy 94.00%, recall 85.90%, precision 96.67%, cross entropy 0.149682
# INFO:absl:Step #975: rate 0.000500, accuracy 92.80%, recall 87.87%, precision 88.35%, cross entropy 0.166688
# INFO:absl:Step #980: rate 0.000500, accuracy 95.60%, recall 89.31%, precision 97.54%, cross entropy 0.109973
# INFO:absl:Step #985: rate 0.000500, accuracy 94.60%, recall 90.07%, precision 94.18%, cross entropy 0.130599
# INFO:absl:Step #990: rate 0.000500, accuracy 94.40%, recall 90.11%, precision 94.79%, cross entropy 0.154767
# INFO:absl:Step #995: rate 0.000500, accuracy 93.60%, recall 88.94%, precision 92.14%, cross entropy 0.145980
# INFO:absl:Step #1000: rate 0.000500, accuracy 94.20%, recall 92.20%, precision 91.06%, cross entropy 0.156581
# INFO:absl:Step 1000: Validation accuracy = 88.53%, recall = 95.35%, precision = 71.13%, fpr = 13.92%, fnr = 4.65% (N=35649)
# INFO:absl:So far the best low false positive rate is 13.10% with false negative rate of 8.45%
# INFO:absl:Step #1005: rate 0.000500, accuracy 94.60%, recall 88.15%, precision 94.55%, cross entropy 0.139554
# INFO:absl:Step #1010: rate 0.000500, accuracy 94.20%, recall 89.88%, precision 92.46%, cross entropy 0.135871
# INFO:absl:Step #1015: rate 0.000500, accuracy 93.60%, recall 91.28%, precision 88.10%, cross entropy 0.141472
# INFO:absl:Step #1020: rate 0.000500, accuracy 94.20%, recall 86.06%, precision 94.78%, cross entropy 0.173905
# INFO:absl:Step #1025: rate 0.000500, accuracy 93.40%, recall 84.92%, precision 93.65%, cross entropy 0.158811
# INFO:absl:Step #1030: rate 0.000500, accuracy 94.80%, recall 89.22%, precision 92.55%, cross entropy 0.130702
# INFO:absl:Step #1035: rate 0.000500, accuracy 94.20%, recall 87.44%, precision 95.80%, cross entropy 0.159564
# INFO:absl:Step #1040: rate 0.000500, accuracy 93.60%, recall 86.80%, precision 94.45%, cross entropy 0.140447
# INFO:absl:Step #1045: rate 0.000500, accuracy 94.40%, recall 89.46%, precision 93.42%, cross entropy 0.133615
# INFO:absl:Step #1050: rate 0.000500, accuracy 95.40%, recall 90.73%, precision 96.20%, cross entropy 0.117074
# INFO:absl:Step #1055: rate 0.000500, accuracy 96.00%, recall 92.43%, precision 96.23%, cross entropy 0.141559
# INFO:absl:Step #1060: rate 0.000500, accuracy 94.20%, recall 88.89%, precision 92.94%, cross entropy 0.145492
# INFO:absl:Step #1065: rate 0.000500, accuracy 94.80%, recall 92.31%, precision 92.25%, cross entropy 0.128100
# INFO:absl:Step #1070: rate 0.000500, accuracy 95.80%, recall 93.03%, precision 95.23%, cross entropy 0.125065
# INFO:absl:Step #1075: rate 0.000500, accuracy 93.80%, recall 89.39%, precision 92.11%, cross entropy 0.150610
# INFO:absl:Step #1080: rate 0.000500, accuracy 93.60%, recall 86.24%, precision 96.24%, cross entropy 0.169194
# INFO:absl:Step #1085: rate 0.000500, accuracy 94.40%, recall 92.46%, precision 90.70%, cross entropy 0.147739
# INFO:absl:Step #1090: rate 0.000500, accuracy 96.00%, recall 94.00%, precision 93.58%, cross entropy 0.126182
# INFO:absl:Step #1095: rate 0.000500, accuracy 94.60%, recall 88.37%, precision 93.65%, cross entropy 0.133620
# INFO:absl:Step #1100: rate 0.000500, accuracy 94.60%, recall 90.34%, precision 93.33%, cross entropy 0.123769
# INFO:absl:Step #1105: rate 0.000500, accuracy 94.20%, recall 86.82%, precision 97.05%, cross entropy 0.146987
# INFO:absl:Step #1110: rate 0.000500, accuracy 93.40%, recall 85.49%, precision 96.40%, cross entropy 0.169866
# INFO:absl:Step #1115: rate 0.000500, accuracy 92.60%, recall 90.75%, precision 84.65%, cross entropy 0.172661
# INFO:absl:Step #1120: rate 0.000500, accuracy 94.20%, recall 90.03%, precision 94.33%, cross entropy 0.144525
# INFO:absl:Step #1125: rate 0.000500, accuracy 93.80%, recall 90.96%, precision 90.38%, cross entropy 0.146232
# INFO:absl:Step #1130: rate 0.000500, accuracy 94.40%, recall 90.65%, precision 92.76%, cross entropy 0.152118
# INFO:absl:Step #1135: rate 0.000500, accuracy 95.80%, recall 94.92%, precision 91.90%, cross entropy 0.109368
# INFO:absl:Step #1140: rate 0.000500, accuracy 93.20%, recall 85.83%, precision 94.78%, cross entropy 0.175074
# INFO:absl:Step #1145: rate 0.000500, accuracy 94.40%, recall 88.46%, precision 93.03%, cross entropy 0.167212
# INFO:absl:Step #1150: rate 0.000500, accuracy 95.80%, recall 94.02%, precision 92.10%, cross entropy 0.128233
# INFO:absl:Step #1155: rate 0.000500, accuracy 92.80%, recall 85.83%, precision 90.79%, cross entropy 0.166417
# INFO:absl:Step #1160: rate 0.000500, accuracy 95.80%, recall 90.00%, precision 96.67%, cross entropy 0.123348
# INFO:absl:Step #1165: rate 0.000500, accuracy 95.80%, recall 92.67%, precision 96.09%, cross entropy 0.127544
# INFO:absl:Step #1170: rate 0.000500, accuracy 94.40%, recall 90.29%, precision 92.22%, cross entropy 0.149382
# INFO:absl:Step #1175: rate 0.000500, accuracy 93.40%, recall 84.64%, precision 96.18%, cross entropy 0.154514
# INFO:absl:Step #1180: rate 0.000500, accuracy 97.00%, recall 94.45%, precision 96.28%, cross entropy 0.097920
# INFO:absl:Step #1185: rate 0.000500, accuracy 94.40%, recall 88.52%, precision 94.85%, cross entropy 0.131268
# INFO:absl:Step #1190: rate 0.000500, accuracy 94.20%, recall 89.39%, precision 93.53%, cross entropy 0.152835
# INFO:absl:Step #1195: rate 0.000500, accuracy 94.80%, recall 90.58%, precision 93.14%, cross entropy 0.116000
# INFO:absl:Step #1200: rate 0.000500, accuracy 95.60%, recall 96.05%, precision 91.46%, cross entropy 0.124362
# INFO:absl:Step #1205: rate 0.000500, accuracy 92.40%, recall 84.36%, precision 92.86%, cross entropy 0.160412
# INFO:absl:Step #1210: rate 0.000500, accuracy 94.20%, recall 87.98%, precision 95.18%, cross entropy 0.148918
# INFO:absl:Step #1215: rate 0.000500, accuracy 95.00%, recall 91.55%, precision 91.89%, cross entropy 0.118904
# INFO:absl:Step #1220: rate 0.000500, accuracy 96.20%, recall 95.07%, precision 93.91%, cross entropy 0.111317
# INFO:absl:Step #1225: rate 0.000500, accuracy 95.60%, recall 92.25%, precision 94.33%, cross entropy 0.127481
# INFO:absl:Step #1230: rate 0.000500, accuracy 95.60%, recall 90.56%, precision 96.34%, cross entropy 0.119140
# INFO:absl:Step #1235: rate 0.000500, accuracy 93.40%, recall 87.05%, precision 93.89%, cross entropy 0.150032
# INFO:absl:Step #1240: rate 0.000500, accuracy 93.80%, recall 89.80%, precision 91.76%, cross entropy 0.148389
# INFO:absl:Step #1245: rate 0.000500, accuracy 94.60%, recall 94.11%, precision 89.70%, cross entropy 0.137570
# INFO:absl:Step #1250: rate 0.000500, accuracy 94.40%, recall 92.49%, precision 90.03%, cross entropy 0.136569
# ...
# Summary on the non-converted ops:
# ---------------------------------
#  * Accepted dialects: tfl, builtin, func
#  * Non-Converted Ops: 37, Total Ops 91, % non-converted = 40.66 %
#  * 37 ARITH ops
#
# - arith.constant:   37 occurrences  (f32: 33, i32: 4)
#
#
#
#   (f32: 3)
#   (f32: 22)
#   (f32: 1)
#   (f32: 1)
#   (f32: 1)
#   (f32: 9)
#   (uq_8: 13)
#   (f32: 1)
# 2024-01-09 16:23:37.204721: I tensorflow/compiler/mlir/lite/flatbuffer_export.cc:2989] Estimated count of arithmetic ops: 4.304 M  ops, equivalently 2.152 M  MACs
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# INFO:absl:Testing tflite model
# /Users/kahrendt/Documents/Hobbies/Programming/Git-Repositories/microWakeWord/microwakeword/test.py:269: RuntimeWarning: invalid value encountered in scalar divide
#   fpr = np.float64(false_positives)/(false_positives+true_negatives)
# INFO:absl:tflite model test: accuracy = 0.958042; recall = 0.958042; precision = 1.000000; fpr = nan; fnr = 0.041958; 1000 out of 9953
# INFO:absl:tflite model test: accuracy = 0.961019; recall = 0.961019; precision = 1.000000; fpr = nan; fnr = 0.038981; 2000 out of 9953
# INFO:absl:tflite model test: accuracy = 0.959014; recall = 0.959014; precision = 1.000000; fpr = nan; fnr = 0.040986; 3000 out of 9953
# INFO:absl:tflite model test: accuracy = 0.959010; recall = 0.959010; precision = 1.000000; fpr = nan; fnr = 0.040990; 4000 out of 9953
# INFO:absl:tflite model test: accuracy = 0.960008; recall = 0.960008; precision = 1.000000; fpr = nan; fnr = 0.039992; 5000 out of 9953
# INFO:absl:tflite model test: accuracy = 0.959673; recall = 0.959673; precision = 1.000000; fpr = nan; fnr = 0.040327; 6000 out of 9953
# INFO:absl:tflite model test: accuracy = 0.959434; recall = 0.959434; precision = 1.000000; fpr = nan; fnr = 0.040566; 7000 out of 9953
# INFO:absl:tflite model test: accuracy = 0.959505; recall = 0.959505; precision = 1.000000; fpr = nan; fnr = 0.040495; 8000 out of 9953
# INFO:absl:tflite model test: accuracy = 0.959782; recall = 0.959782; precision = 1.000000; fpr = nan; fnr = 0.040218; 9000 out of 9953
# INFO:absl:true positives 9555, true negatives 0, false positives 0, false negatives 398
# INFO:absl:Final tflite model test: accuracy = 96.001206%; recall = 96.001206%; precision = 100.000000%; fpr = nan%; fnr = 3.998794%; (N=9953)
# 2024-01-09 16:23:43.853642: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:378] Ignored output_format.
# 2024-01-09 16:23:43.853671: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:381] Ignored drop_control_dependency.
# 2024-01-09 16:23:43.853843: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: trained_models/hey_jarvis_custom_trainer/stream_state_internal
# 2024-01-09 16:23:43.859849: I tensorflow/cc/saved_model/reader.cc:51] Reading meta graph with tags { serve }
# 2024-01-09 16:23:43.859866: I tensorflow/cc/saved_model/reader.cc:146] Reading SavedModel debug info (if present) from: trained_models/hey_jarvis_custom_trainer/stream_state_internal
# 2024-01-09 16:23:43.874714: I tensorflow/cc/saved_model/loader.cc:233] Restoring SavedModel bundle.
# 2024-01-09 16:23:43.992773: I tensorflow/cc/saved_model/loader.cc:217] Running initialization op on SavedModel bundle at path: trained_models/hey_jarvis_custom_trainer/stream_state_internal
# 2024-01-09 16:23:44.037303: I tensorflow/cc/saved_model/loader.cc:316] SavedModel load for tags { serve }; Status: success: OK. Took 183459 microseconds.
# 2024-01-09 16:23:44.255334: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-01-09 16:23:44.255361: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-01-09 16:23:44.255364: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-01-09 16:23:44.255366: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-01-09 16:23:44.255368: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-01-09 16:23:44.255369: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-01-09 16:23:44.255374: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-01-09 16:23:44.255376: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-01-09 16:23:44.255378: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-01-09 16:23:44.255424: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-01-09 16:23:44.255435: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-01-09 16:23:44.255449: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-01-09 16:23:44.255455: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-01-09 16:23:44.255457: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-01-09 16:23:44.255459: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-01-09 16:23:44.255460: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-01-09 16:23:44.255462: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-01-09 16:23:44.255569: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-01-09 16:23:44.255575: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-01-09 16:23:44.255577: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-01-09 16:23:44.255579: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-01-09 16:23:44.255581: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# Summary on the non-converted ops:
# ---------------------------------
#  * Accepted dialects: tfl, builtin, func
#  * Non-Converted Ops: 47, Total Ops 172, % non-converted = 27.33 %
#  * 46 ARITH ops, 1 TF_SAVED_MODEL ops
#
# - arith.constant:   46 occurrences  (f32: 37, i32: 9)
#
#
#
# - tf_saved_model.session_initializer:    1 occurrences
#
#
#   (f32: 14)
#   (f32: 22)
#   (f32: 1)
#   (f32: 1)
#   (f32: 1)
#   (uq_8: 13)
#   (f32: 11)
#   (f32: 1)
#   (f32: 11)
#   (: 22)
# 2024-01-09 16:23:44.256519: I tensorflow/compiler/mlir/lite/flatbuffer_export.cc:2989] Estimated count of arithmetic ops: 0.062 M  ops, equivalently 0.031 M  MACs
# INFO:absl:Testing tflite model
# INFO:absl:tflite model test: accuracy = 0.948052; recall = 0.948052; precision = 1.000000; fpr = nan; fnr = 0.051948; 1000 out of 9953
# INFO:absl:tflite model test: accuracy = 0.957021; recall = 0.957021; precision = 1.000000; fpr = nan; fnr = 0.042979; 2000 out of 9953
# INFO:absl:tflite model test: accuracy = 0.956681; recall = 0.956681; precision = 1.000000; fpr = nan; fnr = 0.043319; 3000 out of 9953
# INFO:absl:tflite model test: accuracy = 0.956511; recall = 0.956511; precision = 1.000000; fpr = nan; fnr = 0.043489; 4000 out of 9953
# INFO:absl:tflite model test: accuracy = 0.956209; recall = 0.956209; precision = 1.000000; fpr = nan; fnr = 0.043791; 5000 out of 9953
# INFO:absl:tflite model test: accuracy = 0.958007; recall = 0.958007; precision = 1.000000; fpr = nan; fnr = 0.041993; 6000 out of 9953
# INFO:absl:tflite model test: accuracy = 0.959577; recall = 0.959577; precision = 1.000000; fpr = nan; fnr = 0.040423; 7000 out of 9953
# INFO:absl:tflite model test: accuracy = 0.959005; recall = 0.959005; precision = 1.000000; fpr = nan; fnr = 0.040995; 8000 out of 9953
# INFO:absl:tflite model test: accuracy = 0.959671; recall = 0.959671; precision = 1.000000; fpr = nan; fnr = 0.040329; 9000 out of 9953
# INFO:absl:true positives 9554, true negatives 0, false positives 0, false negatives 399
# INFO:absl:Final tflite model test: accuracy = 95.991158%; recall = 95.991158%; precision = 100.000000%; fpr = nan%; fnr = 4.008842%; (N=9953)
# 2024-01-09 16:24:19.331614: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:378] Ignored output_format.
# 2024-01-09 16:24:19.331641: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:381] Ignored drop_control_dependency.
# 2024-01-09 16:24:19.331807: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: trained_models/hey_jarvis_custom_trainer/stream_state_internal
# 2024-01-09 16:24:19.337484: I tensorflow/cc/saved_model/reader.cc:51] Reading meta graph with tags { serve }
# 2024-01-09 16:24:19.337499: I tensorflow/cc/saved_model/reader.cc:146] Reading SavedModel debug info (if present) from: trained_models/hey_jarvis_custom_trainer/stream_state_internal
# 2024-01-09 16:24:19.351760: I tensorflow/cc/saved_model/loader.cc:233] Restoring SavedModel bundle.
# 2024-01-09 16:24:19.469081: I tensorflow/cc/saved_model/loader.cc:217] Running initialization op on SavedModel bundle at path: trained_models/hey_jarvis_custom_trainer/stream_state_internal
# 2024-01-09 16:24:19.514405: I tensorflow/cc/saved_model/loader.cc:316] SavedModel load for tags { serve }; Status: success: OK. Took 182597 microseconds.
# 2024-01-09 16:24:19.727606: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-01-09 16:24:19.727626: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-01-09 16:24:19.727629: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-01-09 16:24:19.727631: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-01-09 16:24:19.727633: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-01-09 16:24:19.727635: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-01-09 16:24:19.727637: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-01-09 16:24:19.727639: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-01-09 16:24:19.727640: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-01-09 16:24:19.727658: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-01-09 16:24:19.727664: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-01-09 16:24:19.727674: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-01-09 16:24:19.727676: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-01-09 16:24:19.727678: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-01-09 16:24:19.727679: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-01-09 16:24:19.727681: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-01-09 16:24:19.727683: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-01-09 16:24:19.727842: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-01-09 16:24:19.727845: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-01-09 16:24:19.727847: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-01-09 16:24:19.727849: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-01-09 16:24:19.727851: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# Summary on the non-converted ops:
# ---------------------------------
#  * Accepted dialects: tfl, builtin, func
#  * Non-Converted Ops: 60, Total Ops 172, % non-converted = 34.88 %
#  * 59 ARITH ops, 1 TF_SAVED_MODEL ops
#
# - arith.constant:   59 occurrences  (f32: 50, i32: 9)
#
#
#
# - tf_saved_model.session_initializer:    1 occurrences
#
#
#   (f32: 14)
#   (f32: 22)
#   (f32: 1)
#   (f32: 1)
#   (f32: 1)
#   (f32: 11)
#   (f32: 1)
#   (f32: 11)
#   (: 22)
# 2024-01-09 16:24:19.728676: I tensorflow/compiler/mlir/lite/flatbuffer_export.cc:2989] Estimated count of arithmetic ops: 0.062 M  ops, equivalently 0.031 M  MACs
# fully_quantize: 0, inference_type: 6, input_inference_type: INT8, output_inference_type: UINT8
# 2024-01-09 16:24:20.434705: I tensorflow/compiler/mlir/lite/flatbuffer_export.cc:2989] Estimated count of arithmetic ops: 0.062 M  ops, equivalently 0.031 M  MACs
# INFO:absl:Testing tflite model
# INFO:absl:tflite model test: accuracy = 0.958042; recall = 0.958042; precision = 1.000000; fpr = nan; fnr = 0.041958; 1000 out of 9953
# INFO:absl:tflite model test: accuracy = 0.957021; recall = 0.957021; precision = 1.000000; fpr = nan; fnr = 0.042979; 2000 out of 9953
# INFO:absl:tflite model test: accuracy = 0.955681; recall = 0.955681; precision = 1.000000; fpr = nan; fnr = 0.044319; 3000 out of 9953
# INFO:absl:tflite model test: accuracy = 0.956011; recall = 0.956011; precision = 1.000000; fpr = nan; fnr = 0.043989; 4000 out of 9953
# INFO:absl:tflite model test: accuracy = 0.955009; recall = 0.955009; precision = 1.000000; fpr = nan; fnr = 0.044991; 5000 out of 9953
# INFO:absl:tflite model test: accuracy = 0.953341; recall = 0.953341; precision = 1.000000; fpr = nan; fnr = 0.046659; 6000 out of 9953
# INFO:absl:tflite model test: accuracy = 0.952578; recall = 0.952578; precision = 1.000000; fpr = nan; fnr = 0.047422; 7000 out of 9953
# INFO:absl:tflite model test: accuracy = 0.953631; recall = 0.953631; precision = 1.000000; fpr = nan; fnr = 0.046369; 8000 out of 9953
# INFO:absl:tflite model test: accuracy = 0.953561; recall = 0.953561; precision = 1.000000; fpr = nan; fnr = 0.046439; 9000 out of 9953
# INFO:absl:true positives 9501, true negatives 0, false positives 0, false negatives 452
# INFO:absl:Final tflite model test: accuracy = 95.458656%; recall = 95.458656%; precision = 100.000000%; fpr = nan%; fnr = 4.541344%; (N=9953)
# INFO:absl:DipCo false accepts = 0; false accepts per hour = 0.000000
# INFO:absl:DipCo false accepts = 43; false accepts per hour = 77.400000
# INFO:absl:DipCo false accepts = 83; false accepts per hour = 99.600000
# INFO:absl:DipCo false accepts = 99; false accepts per hour = 89.100000
# INFO:absl:DipCo false accepts = 139; false accepts per hour = 100.080000
# INFO:absl:DipCo false accepts = 139; false accepts per hour = 83.400000
# INFO:absl:DipCo false accepts = 139; false accepts per hour = 71.485714
# INFO:absl:DipCo false accepts = 139; false accepts per hour = 62.550000
# INFO:absl:DipCo false accepts = 139; false accepts per hour = 55.600000
# INFO:absl:DipCo false accepts = 199; false accepts per hour = 71.640000
# INFO:absl:DipCo false accepts = 206; false accepts per hour = 67.418182
# INFO:absl:DipCo false accepts = 227; false accepts per hour = 68.100000
# INFO:absl:DipCo false accepts = 227; false accepts per hour = 62.861538
# INFO:absl:DipCo false accepts = 235; false accepts per hour = 60.428571
# INFO:absl:DipCo false accepts = 243; false accepts per hour = 58.320000
# INFO:absl:DipCo false accepts = 248; false accepts per hour = 55.800000
# INFO:absl:DipCo false accepts = 248; false accepts per hour = 52.517647
# INFO:absl:DipCo false accepts = 263; false accepts per hour = 52.600000
# INFO:absl:DipCo false accepts = 289; false accepts per hour = 54.757895
# INFO:absl:DipCo Total False Accepts = 289; total false accepts per hour = 54.173280
